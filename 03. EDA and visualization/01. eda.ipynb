# %% [markdown]
# # EDA 의미
# * EDA(exploratory Data Analysis)
# * 데이터의 특징, 내재된 관계 파악을 위해 그래프 및 통계적 분석 방법을 활용하여 데이터 탐구하는 것
# * EDA는 저항성 강조, 잔차계산, 자료변수의 재표현, 그래프 통한 현시성 으로 구분

# %% [markdown]
# ![image.png](attachment:2b06891c-64d1-40b3-b51a-ae4dc3afeb17.png)

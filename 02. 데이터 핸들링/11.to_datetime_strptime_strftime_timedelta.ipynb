# %% [markdown]
# # 날짜 데이터 핸들링

# %% [markdown]
# ##  현재날짜 데이터 추출
# * datatime 활용
# * 출력데이터 순서 : year, month, day, hour, minute, second, microsecond

# %%
from datetime import datetime

# %%
datetime.today()
# Out:
# datetime.datetime(2024, 3, 28, 2, 32, 4, 814926)

# %%
datetime.today().year
# Out:
# 2024

# %% [markdown]
# ## 날씨 형식 변환
#
# * df['Datetime'] = pd.to_datetime(df['Datetime'].format = "%Y-%m-%d %H:%M:%S")
# * datetime.strptime('날짜 문자열', '포맷')
# * datetime객체.strftime('포맷')

# %%
datetime.strptime('2022-01-01 03:02:01', "%Y-%m-%d %H:%M:%S")
# Out:
# datetime.datetime(2022, 1, 1, 3, 2, 1)

# %%
time = datetime.today()
time.strftime("%Y-%m-%d %H:%M:%S")
# Out:
# '2024-03-28 02:38:47'

# %% [markdown]
# ![image.png](attachment:fac5e50b-8616-4492-9459-24842ef5312c.png)

# %% [markdown]
# ## 날짜 데이터 연산
# * datetime.timedelta(days = 0, microseconds = 0, milliseconds = 0, minutes = 0, hours = 0, weeks = 0)
#     * 날짜와 시간 사이 차이 계산

# %%
from datetime import timedelta
time = datetime.today()
time + timedelta(days = 100)
# Out:
# datetime.datetime(2024, 7, 6, 2, 43, 11, 498190)
